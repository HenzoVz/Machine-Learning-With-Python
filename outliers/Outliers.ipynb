# %%
import pandas as pd

base = pd.read_csv('../data/credit_data.csv')
base = base.dropna()

# outliers idade
import matplotlib.pyplot as plt
plt.boxplot(base.iloc[:,2], showfliers = True)
#outliers_age = base[(base.age < -20)]
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27d5ca57a20>,
#   <matplotlib.lines.Line2D at 0x27d5ca57d68>],
#  'caps': [<matplotlib.lines.Line2D at 0x27d5ca630f0>,
#   <matplotlib.lines.Line2D at 0x27d5ca63438>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27d5ca578d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27d5ca63780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27d5ca63ac8>],
#  'means': []}

# %%
# outliers loan
plt.boxplot(base.iloc[:,3])
#outliers_loan = base[(base.loan > 13400)]
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27d5caaed30>,
#   <matplotlib.lines.Line2D at 0x27d5cab60b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x27d5cab6400>,
#   <matplotlib.lines.Line2D at 0x27d5cab6748>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27d5caaebe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27d5cab6a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27d5cab6dd8>],
#  'means': []}

# %%
import pandas as pd

base = pd.read_csv('../data/credit_data.csv')
base = base.dropna()
base.loc[base.age < 0, 'age'] = 40.92

# income x age
import matplotlib.pyplot as plt
plt.scatter(base.iloc[:,1], base.iloc[:,2])

# %%
# income x loan
plt.scatter(base.iloc[:,1], base.iloc[:,3])

# %%
# age x loan
plt.scatter(base.iloc[:,2], base.iloc[:,3])

# %%
base_census = pd.read_csv('../data/census.csv')

# age x final weight
plt.scatter(base_census.iloc[:, 0], base_census.iloc[:,2])

# %%
import pandas as pd

base = pd.read_csv('../data/credit_data.csv')
base = base.dropna()

from pyod.models.knn import KNN
detector = KNN()
detector.fit(base.iloc[:,1:4])

previsoes = detector.labels_
confianca_previsoes = detector.decision_scores_

outliers = []
for i in range(len(previsoes)):
    #print(previsoes[i])
    if previsoes[i] == 1:
        outliers.append(i)
        
lista_outliers = base.iloc[outliers, :]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-ceef3b89f166> in <module>
#       4 base = base.dropna()
#       5
# ----> 6 from pyod.models.knn import KNN
#       7 detector = KNN()
#       8 detector.fit(base.iloc[:,1:4])
#
# ModuleNotFoundError: No module named 'pyod'
