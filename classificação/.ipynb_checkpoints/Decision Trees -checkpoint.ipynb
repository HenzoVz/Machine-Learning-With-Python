# %% [markdown]
# ### Decision Trees

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

# %%
data = pd.read_csv('../data/Iris.csv')
data = data.rename(index=str, columns={"Species": "Class"})

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm        Class
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['Class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Class, dtype: int64

# %%
#sns.pairplot(data,hue='Class',palette='Set2')

# %%
X = data.drop(['Class','Id'],axis=1).values
y = data['Class'].values

#from sklearn.preprocessing import LabelEncoder
#labelencoder_forecast = LabelEncoder()
#y = labelencoder_forecast.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

classifier_dt = DecisionTreeClassifier(random_state=1986, criterion='gini', max_depth=5)
classifier_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1986,
#             splitter='best')

# %%
from sklearn.model_selection import cross_val_score

scores_dt = cross_val_score(classifier_dt, X, y, scoring='accuracy', cv=5)
print(scores_dt.mean())
# Out:
# 0.9666666666666668

# %%
classifier_dt_pred = classifier_dt.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics

# %%
print(classification_report(y_test,classifier_dt_pred))
print("Decision Tree model accuracy(in %):", metrics.accuracy_score(y_test, classifier_dt_pred)*100)
print(confusion_matrix(y_test,classifier_dt_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.80      0.94      0.86        17
#  Iris-virginica       0.90      0.69      0.78        13
#
#       micro avg       0.89      0.89      0.89        45
#       macro avg       0.90      0.88      0.88        45
#    weighted avg       0.90      0.89      0.89        45
#
# Decision Tree model accuracy(in %): 88.88888888888889
# [[15  0  0]
#  [ 0 16  1]
#  [ 0  4  9]]

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(data.columns[1:5])
print(features)
np.asarray(class_names)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
dot_data = StringIO()  
export_graphviz(classifier_dt, out_file=dot_data,feature_names=features, class_names= target_names_iris ,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %%
# Exemplo  utilizado para validar o modelo
sample1 = [5.1, 3.5, 1.4, 0.2]  # Iris-setosa
sample2 = [7.0, 3.2, 4.7, 1.4]   # Iris-versicolor
sample3 = [6.9, 3.2, 5.7, 2.3]     # Iris-virginica

classifier_dt.predict([sample1, sample2, sample3])  # Predizendo o tipo da flor
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)
